# %%
# %matplotlib inline 
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
full_tile = cv2.imread('../data/sample/tiles/a13220033231221232.jpeg')
tile_0 = cv2.imread('../data/sample/tiles/a132200332312212320.jpeg')
tile_1 = cv2.imread('../data/sample/tiles/a132200332312212321.jpeg')
tile_2 = cv2.imread('../data/sample/tiles/a132200332312212322.jpeg')
tile_3 = cv2.imread('../data/sample/tiles/a132200332312212323.jpeg')

# %%
plt.imshow(cv2.cvtColor(tile_0, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(full_tile, cv2.COLOR_BGR2RGB))

# %%
cv2.imshow('test', tile_1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
tile_0.shape
# Out:
# (256, 256, 3)

# %%
zoomed_full_tile = np.zeros((512, 512, 3), np.uint8)
zoomed_full_tile.shape
# Out:
# (512, 512, 3)

# %%
zoomed_full_tile[:256, :256] = tile_0[:256, :256]
zoomed_full_tile[:256:, 256:] = tile_1[:256, :256]
zoomed_full_tile[256:, :256] = tile_2[:256, :256]
zoomed_full_tile[256:, 256:] = tile_3[:256, :256]

# %%
plt.imshow(cv2.cvtColor(zoomed_full_tile, cv2.COLOR_BGR2RGB))
